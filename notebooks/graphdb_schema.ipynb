# %%
from langchain_community.graphs import Neo4jGraph

# Connect to Neo4j
graph = Neo4jGraph(
    url="neo4j+s://f5886a71.databases.neo4j.io",
    username="neo4j",
    password="fFCqS5-Ak3ZLppY0p1e2rrL1ZN_FJwt7oH_McxlCh5o"
)

print("✓ Connected to Neo4j")
# Out:
# /var/folders/_n/46drt9kd1_76dqk_vj0xk9qm0000gn/T/ipykernel_11658/1426366927.py:4: LangChainDeprecationWarning: The class `Neo4jGraph` was deprecated in LangChain 0.3.8 and will be removed in 1.0. An updated version of the class exists in the `langchain-neo4j package and should be used instead. To use it run `pip install -U `langchain-neo4j` and import as `from `langchain_neo4j import Neo4jGraph``.
#   graph = Neo4jGraph(
# ✓ Connected to Neo4j

# %%
# %store -r champion_full_data

# Then take the first 10:
# champions_to_process = champion_full_data[:10]

# For now, let's check if the variable exists
try:
    print(f"Champion data available: {len(champion_full_data)} champions")
    champions_to_process = champion_full_data
    for i, champ in enumerate(champions_to_process, 1):
        print(f"  {i}. {champ['name']}")
except NameError:
    print("⚠️ champion_full_data not found!")
# Out:
# Champion data available: 172 champions
#   1. Annie
#   2. Olaf
#   3. Galio
#   4. Twisted Fate
#   5. Xin Zhao
#   6. Urgot
#   7. LeBlanc
#   8. Vladimir
#   9. Fiddlesticks
#   10. Kayle
#   11. Master Yi
#   12. Alistar
#   13. Ryze
#   14. Sion
#   15. Sivir
#   16. Soraka
#   17. Teemo
#   18. Tristana
#   19. Warwick
#   20. Nunu & Willump
#   21. Miss Fortune
#   22. Ashe
#   23. Tryndamere
#   24. Jax
#   25. Morgana
#   26. Zilean
#   27. Singed
#   28. Evelynn
#   29. Twitch
#   30. Karthus
#   31. Cho'Gath
#   32. Amumu
#   33. Rammus
#   34. Anivia
#   35. Shaco
#   36. Dr. Mundo
#   37. Sona
#   38. Kassadin
#   39. Irelia
#   40. Janna
#   41. Gangplank
#   42. Corki
#   43. Karma
#   44. Taric
#   45. Veigar
#   46. Trundle
#   47. Swain
#   48. Caitlyn
#   49. Blitzcrank
#   50. Malphite
#   51. Katarina
#   52. Nocturne
#   53. Maokai
#   54. Renekton
#   55. Jarvan IV
#   56. Elise
#   57. Orianna
#   58. Wukong
#   59. Brand
#   60. Lee Sin
#   61. Vayne
#   62. Rumble
#   63. Cassiopeia
#   64. Skarner
#   65. Heimerdinger
#   66. Nasus
#   67. Nidalee
#   68. Udyr
#   69. Poppy
#   70. Gragas
#   71. Pantheon
#   72. Ezreal
#   73. Mordekaiser
#   74. Yorick
#   75. Akali
#   76. Kennen
#   77. Garen
#   78. Leona
#   79. Malzahar
#   80. Talon
#   81. Riven
#   82. Kog'Maw
#   83. Shen
#   84. Lux
#   85. Xerath
#   86. Shyvana
#   87. Ahri
#   88. Graves
#   89. Fizz
#   90. Volibear
#   91. Rengar
#   92. Varus
#   93. Nautilus
#   94. Viktor
#   95. Sejuani
#   96. Fiora
#   97. Ziggs
#   98. Lulu
#   99. Draven
#   100. Hecarim
#   101. Kha'Zix
#   102. Darius
#   103. Jayce
#   104. Lissandra
#   105. Diana
#   106. Quinn
#   107. Syndra
#   108. Aurelion Sol
#   109. Kayn
#   110. Zoe
#   111. Zyra
#   112. Kai'Sa
#   113. Seraphine
#   114. Gnar
#   115. Zac
#   116. Yasuo
#   117. Vel'Koz
#   118. Taliyah
#   119. Camille
#   120. Akshan
#   121. Bel'Veth
#   122. Braum
#   123. Jhin
#   124. Kindred
#   125. Zeri
#   126. Jinx
#   127. Tahm Kench
#   128. Briar
#   129. Viego
#   130. Senna
#   131. Lucian
#   132. Zed
#   133. Kled
#   134. Ekko
#   135. Qiyana
#   136. Vi
#   137. Aatrox
#   138. Nami
#   139. Azir
#   140. Yuumi
#   141. Samira
#   142. Thresh
#   143. Illaoi
#   144. Rek'Sai
#   145. Ivern
#   146. Kalista
#   147. Bard
#   148. Rakan
#   149. Xayah
#   150. Ornn
#   151. Sylas
#   152. Neeko
#   153. Aphelios
#   154. Rell
#   155. Pyke
#   156. Vex
#   157. Yone
#   158. Ambessa
#   159. Mel
#   160. Yunara
#   161. Sett
#   162. Lillia
#   163. Gwen
#   164. Renata Glasc
#   165. Aurora
#   166. Nilah
#   167. K'Sante
#   168. Smolder
#   169. Milio
#   170. Zaahen
#   171. Hwei
#   172. Naafiri

# %%
def create_champion(graph, champion_data):
    
    """
    Creates a Champion node with all its properties and role relationships.
    
    Args:
        graph: Neo4j graph connection
        champion_data: Dict with champion info from JSON
    
    Returns:
        Champion name (str)
    """
    # Extract basic info
    champ_id = champion_data['id']
    name = champion_data['name']
    title = champion_data['title']
    roles = champion_data.get('roles', [])  # Use .get() in case missing
    
    # Get tactical info (with defaults)
    tactical = champion_data.get('tacticalInfo', {})
    damage_type = tactical.get('damageType', 'unknown')
    attack_type = tactical.get('attackType', 'unknown')
    difficulty = tactical.get('difficulty', 0)
    
    # Create Champion node
    create_champ_query = """
    MERGE (c:Champion {id: $champion_id})
    SET c.name = $name,
        c.title = $title,
        c.damageType = $damageType,
        c.attackType = $attackType,
        c.difficulty = $difficulty
    RETURN c.name as name
    """
    
    graph.query(
        create_champ_query,
        params={
            'champion_id': champ_id,
            'name': name,
            'title': title,
            'damageType': damage_type,
            'attackType': attack_type,
            'difficulty': difficulty
        }
    )
    
    # Create Role relationships
    create_role_query = """
    MATCH (c:Champion {id: $champion_id})
    MERGE (r:Role {name: $role_name})
    MERGE (c)-[:HAS_ROLE]->(r)
    """
    
    for role in roles:
        graph.query(
            create_role_query,
            params={
                'champion_id': champ_id,
                'role_name': role.capitalize()
            }
        )
    
    return name


def create_abilities(graph, champion_data):
    """
    Creates Ability nodes and HAS_ABILITY relationships.
    
    Args:
        graph: Neo4j graph connection
        champion_data: Dict with champion info from JSON
    
    Returns:
        Number of abilities created (int)
    """
    champ_id = champion_data['id']
    abilities_created = 0
    
    # Create ability creation query
    create_ability_query = """
    MATCH (c:Champion {id: $champion_id})
    MERGE (a:Ability {id: $ability_id})
    SET a.name = $ability_name,
        a.slot = $slot,
        a.description = $description
    MERGE (c)-[:HAS_ABILITY]->(a)
    RETURN a.name as name
    """
    
    # 1. Process Passive
    passive = champion_data.get('passive')
    if passive:
        ability_id = f"{champ_id}_passive"
        graph.query(
            create_ability_query,
            params={
                'champion_id': champ_id,
                'ability_id': ability_id,
                'ability_name': passive.get('name', 'Unknown'),
                'slot': 'Passive',
                'description': passive.get('description', '')
            }
        )
        abilities_created += 1
    
    # 2. Process Spells (Q, W, E, R)
    spells = champion_data.get('spells', [])
    for spell in spells:
        spell_key = spell.get('spellKey', '').upper()  # 'q' -> 'Q'
        ability_id = f"{champ_id}_{spell_key.lower()}"
        
        graph.query(
            create_ability_query,
            params={
                'champion_id': champ_id,
                'ability_id': ability_id,
                'ability_name': spell.get('name', 'Unknown'),
                'slot': spell_key,
                'description': spell.get('description', '')
            }
        )
        abilities_created += 1
    
    return abilities_created

print("✓ Helper functions defined")
# Out:
# ✓ Helper functions defined

# %%
# Process 10 champions
print("Starting ingestion...\n")

total_abilities = 0

for i, champ_data in enumerate(champions_to_process, 1):
    # Create champion and roles
    champ_name = create_champion(graph, champ_data)
    
    # Create abilities
    ability_count = create_abilities(graph, champ_data)
    total_abilities += ability_count
    
    print(f"✓ {i}/10: {champ_name} ({ability_count} abilities)")

print(f"\n🎉 Success! Created {len(champions_to_process)} champions with {total_abilities} total abilities")
# Out:
# Starting ingestion...
#
# ✓ 1/10: Annie (5 abilities)
# ✓ 2/10: Olaf (5 abilities)
# ✓ 3/10: Galio (5 abilities)
# ✓ 4/10: Twisted Fate (5 abilities)
# ✓ 5/10: Xin Zhao (5 abilities)
# ✓ 6/10: Urgot (5 abilities)
# ✓ 7/10: LeBlanc (5 abilities)
# ✓ 8/10: Vladimir (5 abilities)
# ✓ 9/10: Fiddlesticks (5 abilities)
# ✓ 10/10: Kayle (5 abilities)
# ✓ 11/10: Master Yi (5 abilities)
# ✓ 12/10: Alistar (5 abilities)
# ✓ 13/10: Ryze (5 abilities)
# ✓ 14/10: Sion (5 abilities)
# ✓ 15/10: Sivir (5 abilities)
# ✓ 16/10: Soraka (5 abilities)
# ✓ 17/10: Teemo (5 abilities)
# ✓ 18/10: Tristana (5 abilities)
# ✓ 19/10: Warwick (5 abilities)
# ✓ 20/10: Nunu & Willump (5 abilities)
# ✓ 21/10: Miss Fortune (5 abilities)
# ✓ 22/10: Ashe (5 abilities)
# ✓ 23/10: Tryndamere (5 abilities)
# ✓ 24/10: Jax (5 abilities)
# ✓ 25/10: Morgana (5 abilities)
# ✓ 26/10: Zilean (5 abilities)
# ✓ 27/10: Singed (5 abilities)
# ✓ 28/10: Evelynn (5 abilities)
# ✓ 29/10: Twitch (5 abilities)
# ✓ 30/10: Karthus (5 abilities)
# ✓ 31/10: Cho'Gath (5 abilities)
# ✓ 32/10: Amumu (5 abilities)
# ✓ 33/10: Rammus (5 abilities)
# ✓ 34/10: Anivia (5 abilities)
# ✓ 35/10: Shaco (5 abilities)
# ✓ 36/10: Dr. Mundo (5 abilities)
# ✓ 37/10: Sona (5 abilities)
# ✓ 38/10: Kassadin (5 abilities)
# ✓ 39/10: Irelia (5 abilities)
# ✓ 40/10: Janna (5 abilities)
# ✓ 41/10: Gangplank (5 abilities)
# ✓ 42/10: Corki (5 abilities)
# ✓ 43/10: Karma (5 abilities)
# ✓ 44/10: Taric (5 abilities)
# ✓ 45/10: Veigar (5 abilities)
# ✓ 46/10: Trundle (5 abilities)
# ✓ 47/10: Swain (5 abilities)
# ✓ 48/10: Caitlyn (5 abilities)
# ✓ 49/10: Blitzcrank (5 abilities)
# ✓ 50/10: Malphite (5 abilities)
# ✓ 51/10: Katarina (5 abilities)
# ✓ 52/10: Nocturne (5 abilities)
# ✓ 53/10: Maokai (5 abilities)
# ✓ 54/10: Renekton (5 abilities)
# ✓ 55/10: Jarvan IV (5 abilities)
# ✓ 56/10: Elise (5 abilities)
# ✓ 57/10: Orianna (5 abilities)
# ✓ 58/10: Wukong (5 abilities)
# ✓ 59/10: Brand (5 abilities)
# ✓ 60/10: Lee Sin (5 abilities)
# ✓ 61/10: Vayne (5 abilities)
# ✓ 62/10: Rumble (5 abilities)
# ✓ 63/10: Cassiopeia (5 abilities)
# ✓ 64/10: Skarner (5 abilities)
# ✓ 65/10: Heimerdinger (5 abilities)
# ✓ 66/10: Nasus (5 abilities)
# ✓ 67/10: Nidalee (5 abilities)
# ✓ 68/10: Udyr (5 abilities)
# ✓ 69/10: Poppy (5 abilities)
# ✓ 70/10: Gragas (5 abilities)
# ✓ 71/10: Pantheon (5 abilities)
# ✓ 72/10: Ezreal (5 abilities)
# ✓ 73/10: Mordekaiser (5 abilities)
# ✓ 74/10: Yorick (5 abilities)
# ✓ 75/10: Akali (5 abilities)
# ✓ 76/10: Kennen (5 abilities)
# ✓ 77/10: Garen (5 abilities)
# ✓ 78/10: Leona (5 abilities)
# ✓ 79/10: Malzahar (5 abilities)
# ✓ 80/10: Talon (5 abilities)
# ✓ 81/10: Riven (5 abilities)
# ✓ 82/10: Kog'Maw (5 abilities)
# ✓ 83/10: Shen (5 abilities)
# ✓ 84/10: Lux (5 abilities)
# ✓ 85/10: Xerath (5 abilities)
# ✓ 86/10: Shyvana (5 abilities)
# ✓ 87/10: Ahri (5 abilities)
# ✓ 88/10: Graves (5 abilities)
# ✓ 89/10: Fizz (5 abilities)
# ✓ 90/10: Volibear (5 abilities)
# ✓ 91/10: Rengar (5 abilities)
# ✓ 92/10: Varus (5 abilities)
# ✓ 93/10: Nautilus (5 abilities)
# ✓ 94/10: Viktor (5 abilities)
# ✓ 95/10: Sejuani (5 abilities)
# ✓ 96/10: Fiora (5 abilities)
# ✓ 97/10: Ziggs (5 abilities)
# ✓ 98/10: Lulu (5 abilities)
# ✓ 99/10: Draven (5 abilities)
# ✓ 100/10: Hecarim (5 abilities)
# ✓ 101/10: Kha'Zix (5 abilities)
# ✓ 102/10: Darius (5 abilities)
# ✓ 103/10: Jayce (5 abilities)
# ✓ 104/10: Lissandra (5 abilities)
# ✓ 105/10: Diana (5 abilities)
# ✓ 106/10: Quinn (5 abilities)
# ✓ 107/10: Syndra (5 abilities)
# ✓ 108/10: Aurelion Sol (5 abilities)
# ✓ 109/10: Kayn (5 abilities)
# ✓ 110/10: Zoe (5 abilities)
# ✓ 111/10: Zyra (5 abilities)
# ✓ 112/10: Kai'Sa (5 abilities)
# ✓ 113/10: Seraphine (5 abilities)
# ✓ 114/10: Gnar (5 abilities)
# ✓ 115/10: Zac (5 abilities)
# ✓ 116/10: Yasuo (5 abilities)
# ✓ 117/10: Vel'Koz (5 abilities)
# ✓ 118/10: Taliyah (5 abilities)
# ✓ 119/10: Camille (5 abilities)
# ✓ 120/10: Akshan (5 abilities)
# ✓ 121/10: Bel'Veth (5 abilities)
# ✓ 122/10: Braum (5 abilities)
# ✓ 123/10: Jhin (5 abilities)
# ✓ 124/10: Kindred (5 abilities)
# ✓ 125/10: Zeri (5 abilities)
# ✓ 126/10: Jinx (5 abilities)
# ✓ 127/10: Tahm Kench (5 abilities)
# ✓ 128/10: Briar (5 abilities)
# ✓ 129/10: Viego (5 abilities)
# ✓ 130/10: Senna (5 abilities)
# ✓ 131/10: Lucian (5 abilities)
# ✓ 132/10: Zed (5 abilities)
# ✓ 133/10: Kled (5 abilities)
# ✓ 134/10: Ekko (5 abilities)
# ✓ 135/10: Qiyana (5 abilities)
# ✓ 136/10: Vi (5 abilities)
# ✓ 137/10: Aatrox (5 abilities)
# ✓ 138/10: Nami (5 abilities)
# ✓ 139/10: Azir (5 abilities)
# ✓ 140/10: Yuumi (5 abilities)
# ✓ 141/10: Samira (5 abilities)
# ✓ 142/10: Thresh (5 abilities)
# ✓ 143/10: Illaoi (5 abilities)
# ✓ 144/10: Rek'Sai (5 abilities)
# ✓ 145/10: Ivern (5 abilities)
# ✓ 146/10: Kalista (5 abilities)
# ✓ 147/10: Bard (5 abilities)
# ✓ 148/10: Rakan (5 abilities)
# ✓ 149/10: Xayah (5 abilities)
# ✓ 150/10: Ornn (5 abilities)
# ✓ 151/10: Sylas (5 abilities)
# ✓ 152/10: Neeko (5 abilities)
# ✓ 153/10: Aphelios (5 abilities)
# ✓ 154/10: Rell (5 abilities)
# ✓ 155/10: Pyke (5 abilities)
# ✓ 156/10: Vex (5 abilities)
# ✓ 157/10: Yone (5 abilities)
# ✓ 158/10: Ambessa (5 abilities)
# ✓ 159/10: Mel (5 abilities)
# ✓ 160/10: Yunara (5 abilities)
# ✓ 161/10: Sett (5 abilities)
# ✓ 162/10: Lillia (5 abilities)
# ✓ 163/10: Gwen (5 abilities)
# ✓ 164/10: Renata Glasc (5 abilities)
# ✓ 165/10: Aurora (5 abilities)
# ✓ 166/10: Nilah (5 abilities)
# ✓ 167/10: K'Sante (5 abilities)
# ✓ 168/10: Smolder (5 abilities)
# ✓ 169/10: Milio (5 abilities)
# ✓ 170/10: Zaahen (5 abilities)
# ✓ 171/10: Hwei (5 abilities)
# ✓ 172/10: Naafiri (5 abilities)
#
# 🎉 Success! Created 172 champions with 860 total abilities

# %%
import re
def extract_damage_types(description):
    """
    Extract damage types from ability description.
    
    Returns: List of damage types found
    """
    damage_types = []
    text = description.lower()
    
    # Check for explicit damage type tags
    if '<magicdamage>' in text or 'magic damage' in text:
        damage_types.append('Magic')
    if '<physicaldamage>' in text or 'physical damage' in text:
        damage_types.append('Physical')
    if '<truedamage>' in text or 'true damage' in text:
        damage_types.append('True')
    
    return damage_types


def extract_crowd_control(description):
    """
    Extract crowd control effects from ability description.
    
    Returns: List of CC types found
    """
    cc_types = []
    text = description.lower()
    
    # CC keywords - order matters (check specific before general)
    cc_keywords = {
        'Stun': r'\bstun',
        'Root': r'\broot',
        'Knockup': r'\bknock(s|ing)?\s+up',
        'Knockback': r'\bknock(s|ing)?\s+(back|away)',
        'Taunt': r'\btaunt',
        'Charm': r'\bcharm',
        'Fear': r'\bfear',
        'Slow': r'\bslow',
        'Blind': r'\bblind',
        'Silence': r'\bsilence',
        'Grounded': r'\bground',
        'Disarm': r'\bdisarm',
        'Suppress': r'\bsuppress'
    }
    
    for cc_name, pattern in cc_keywords.items():
        if re.search(pattern, text):
            cc_types.append(cc_name)
    
    return cc_types


def extract_scaling_stats(description):
    """
    Extract what stats the ability scales with.
    
    Returns: List of stats found
    """
    stats = []
    text = description.lower()
    
    # Stat keywords
    stat_keywords = {
        'AP': r'\bability power|\bap\b',
        'AD': r'\battack damage|\bad\b|\bbad\b|bonus attack damage',
        'Health': r'\bmax(imum)?\s+health|\bbonushealth|\bbonus health',
        'Armor': r'\barmor',
        'MagicResist': r'\bmagic resist',
        'AttackSpeed': r'\battack speed',
        'CriticalStrike': r'\bcritical strike|\bcrit'
    }
    
    for stat_name, pattern in stat_keywords.items():
        if re.search(pattern, text):
            stats.append(stat_name)
    
    return stats


def extract_effect_types(description):
    """
    Extract effect types (utility, mobility, etc.).
    
    Returns: List of effects found
    """
    effects = []
    text = description.lower()
    
    # Effect keywords
    effect_keywords = {
        'Shield': r'\b<shield>|shield',
        'Heal': r'\bheal|\bhealing',
        'Dash': r'\bdash',
        'Blink': r'\bblink|\bteleport',
        'Stealth': r'\bstealth|\binvisib',
        'Movement': r'\bmove(ment)?\s+speed|\bms\b',
        'AttackSpeed': r'\battack\s+speed',
        'Lifesteal': r'\blifesteal|\blife\s+steal',
        'Vamp': r'\bspell\s+vamp'
    }
    
    for effect_name, pattern in effect_keywords.items():
        if re.search(pattern, text):
            effects.append(effect_name)
    
    return effects


print("✓ Parser functions defined")

# Test on Annie's passive
test_desc = "After casting 4 spells, Annie's next offensive spell will stun the target."
print(f"\nTest on: '{test_desc}'")
print(f"  CC found: {extract_crowd_control(test_desc)}")
# Out:
# ✓ Parser functions defined
#
# Test on: 'After casting 4 spells, Annie's next offensive spell will stun the target.'
#   CC found: ['Stun']

# %%
# Add champion-level relationships
champion_query = """
MATCH (c:Champion {id: $champion_id})
MERGE (at:AttackType {name: $attack_type})
MERGE (c)-[:ATTACKS_WITH]->(at)
"""

print("Adding champion-level relationships...\n")

for champ in champions_to_process:
    tactical = champ.get('tacticalInfo', {})
    attack_type = tactical.get('attackType', 'unknown').capitalize()
    
    graph.query(
        champion_query,
        params={
            'champion_id': champ['id'],
            'attack_type': attack_type
        }
    )
    
    print(f"✓ {champ['name']}: {attack_type}")

print("\n✓ Champion relationships added")
# Out:
# Adding champion-level relationships...
#
# ✓ Annie: Ranged
# ✓ Olaf: Melee
# ✓ Galio: Melee
# ✓ Twisted Fate: Ranged
# ✓ Xin Zhao: Melee
# ✓ Urgot: Ranged
# ✓ LeBlanc: Ranged
# ✓ Vladimir: Ranged
# ✓ Fiddlesticks: Ranged
# ✓ Kayle: Melee
# ✓ Master Yi: Melee
# ✓ Alistar: Melee
# ✓ Ryze: Ranged
# ✓ Sion: Melee
# ✓ Sivir: Ranged
# ✓ Soraka: Ranged
# ✓ Teemo: Ranged
# ✓ Tristana: Ranged
# ✓ Warwick: Melee
# ✓ Nunu & Willump: Melee
# ✓ Miss Fortune: Ranged
# ✓ Ashe: Ranged
# ✓ Tryndamere: Melee
# ✓ Jax: Melee
# ✓ Morgana: Ranged
# ✓ Zilean: Ranged
# ✓ Singed: Melee
# ✓ Evelynn: Melee
# ✓ Twitch: Ranged
# ✓ Karthus: Ranged
# ✓ Cho'Gath: Melee
# ✓ Amumu: Melee
# ✓ Rammus: Melee
# ✓ Anivia: Ranged
# ✓ Shaco: Melee
# ✓ Dr. Mundo: Melee
# ✓ Sona: Ranged
# ✓ Kassadin: Melee
# ✓ Irelia: Melee
# ✓ Janna: Ranged
# ✓ Gangplank: Melee
# ✓ Corki: Ranged
# ✓ Karma: Ranged
# ✓ Taric: Melee
# ✓ Veigar: Ranged
# ✓ Trundle: Melee
# ✓ Swain: Ranged
# ✓ Caitlyn: Ranged
# ✓ Blitzcrank: Melee
# ✓ Malphite: Melee
# ✓ Katarina: Melee
# ✓ Nocturne: Melee
# ✓ Maokai: Melee
# ✓ Renekton: Melee
# ✓ Jarvan IV: Melee
# ✓ Elise: Ranged
# ✓ Orianna: Ranged
# ✓ Wukong: Melee
# ✓ Brand: Ranged
# ✓ Lee Sin: Melee
# ✓ Vayne: Ranged
# ✓ Rumble: Melee
# ✓ Cassiopeia: Ranged
# ✓ Skarner: Melee
# ✓ Heimerdinger: Ranged
# ✓ Nasus: Melee
# ✓ Nidalee: Ranged
# ✓ Udyr: Melee
# ✓ Poppy: Melee
# ✓ Gragas: Melee
# ✓ Pantheon: Melee
# ✓ Ezreal: Ranged
# ✓ Mordekaiser: Melee
# ✓ Yorick: Melee
# ✓ Akali: Melee
# ✓ Kennen: Ranged
# ✓ Garen: Melee
# ✓ Leona: Melee
# ✓ Malzahar: Ranged
# ✓ Talon: Melee
# ✓ Riven: Melee
# ✓ Kog'Maw: Ranged
# ✓ Shen: Melee
# ✓ Lux: Ranged
# ✓ Xerath: Ranged
# ✓ Shyvana: Melee
# ✓ Ahri: Ranged
# ✓ Graves: Ranged
# ✓ Fizz: Melee
# ✓ Volibear: Melee
# ✓ Rengar: Melee
# ✓ Varus: Ranged
# ✓ Nautilus: Melee
# ✓ Viktor: Ranged
# ✓ Sejuani: Melee
# ✓ Fiora: Melee
# ✓ Ziggs: Ranged
# ✓ Lulu: Ranged
# ✓ Draven: Ranged
# ✓ Hecarim: Melee
# ✓ Kha'Zix: Melee
# ✓ Darius: Melee
# ✓ Jayce: Ranged
# ✓ Lissandra: Ranged
# ✓ Diana: Melee
# ✓ Quinn: Ranged
# ✓ Syndra: Ranged
# ✓ Aurelion Sol: Ranged
# ✓ Kayn: Melee
# ✓ Zoe: Ranged
# ✓ Zyra: Ranged
# ✓ Kai'Sa: Ranged
# ✓ Seraphine: Ranged
# ✓ Gnar: Ranged
# ✓ Zac: Melee
# ✓ Yasuo: Melee
# ✓ Vel'Koz: Ranged
# ✓ Taliyah: Ranged
# ✓ Camille: Melee
# ✓ Akshan: Ranged
# ✓ Bel'Veth: Melee
# ✓ Braum: Melee
# ✓ Jhin: Ranged
# ✓ Kindred: Ranged
# ✓ Zeri: Ranged
# ✓ Jinx: Ranged
# ✓ Tahm Kench: Melee
# ✓ Briar: Melee
# ✓ Viego: Melee
# ✓ Senna: Ranged
# ✓ Lucian: Ranged
# ✓ Zed: Melee
# ✓ Kled: Melee
# ✓ Ekko: Melee
# ✓ Qiyana: Melee
# ✓ Vi: Melee
# ✓ Aatrox: Melee
# ✓ Nami: Ranged
# ✓ Azir: Ranged
# ✓ Yuumi: Ranged
# ✓ Samira: Ranged
# ✓ Thresh: Ranged
# ✓ Illaoi: Melee
# ✓ Rek'Sai: Melee
# ✓ Ivern: Ranged
# ✓ Kalista: Ranged
# ✓ Bard: Ranged
# ✓ Rakan: Melee
# ✓ Xayah: Ranged
# ✓ Ornn: Melee
# ✓ Sylas: Melee
# ✓ Neeko: Ranged
# ✓ Aphelios: Ranged
# ✓ Rell: Melee
# ✓ Pyke: Melee
# ✓ Vex: Ranged
# ✓ Yone: Melee
# ✓ Ambessa: Melee
# ✓ Mel: Ranged
# ✓ Yunara: Ranged
# ✓ Sett: Melee
# ✓ Lillia: Melee
# ✓ Gwen: Melee
# ✓ Renata Glasc: Ranged
# ✓ Aurora: Ranged
# ✓ Nilah: Melee
# ✓ K'Sante: Melee
# ✓ Smolder: Ranged
# ✓ Milio: Ranged
# ✓ Zaahen: Melee
# ✓ Hwei: Ranged
# ✓ Naafiri: Melee
#
# ✓ Champion relationships added

# %%
def enrich_ability(graph, champion_id, spell_data, slot):
    """
    Parse ability description and create relationships.
    """
    ability_id = f"{champion_id}_{slot.lower() if slot != 'Passive' else 'passive'}"
    
    # Get descriptions
    description = spell_data.get('description', '')
    dynamic_desc = spell_data.get('dynamicDescription', '')
    full_text = f"{description} {dynamic_desc}"
    
    # Extract all data
    damage_types = extract_damage_types(full_text)
    cc_types = extract_crowd_control(full_text)
    scaling_stats = extract_scaling_stats(full_text)
    effect_types = extract_effect_types(full_text)
    
    # Create damage type relationships
    for dmg_type in damage_types:
        query = """
        MATCH (a:Ability {id: $ability_id})
        MERGE (dt:DamageType {name: $damage_type})
        MERGE (a)-[:DEALS]->(dt)
        """
        graph.query(query, params={'ability_id': ability_id, 'damage_type': dmg_type})
    
    # Create CC relationships
    for cc in cc_types:
        query = """
        MATCH (a:Ability {id: $ability_id})
        MERGE (cc:CrowdControl {name: $cc_type})
        MERGE (a)-[:APPLIES]->(cc)
        """
        graph.query(query, params={'ability_id': ability_id, 'cc_type': cc})
    
    # Create scaling relationships
    for stat in scaling_stats:
        query = """
        MATCH (a:Ability {id: $ability_id})
        MERGE (s:Stat {name: $stat_name})
        MERGE (a)-[:SCALES_WITH]->(s)
        """
        graph.query(query, params={'ability_id': ability_id, 'stat_name': stat})
    
    # Create effect relationships
    for effect in effect_types:
        query = """
        MATCH (a:Ability {id: $ability_id})
        MERGE (e:EffectType {name: $effect_name})
        MERGE (a)-[:HAS_EFFECT]->(e)
        """
        graph.query(query, params={'ability_id': ability_id, 'effect_name': effect})
    
    return {
        'damage': damage_types,
        'cc': cc_types,
        'scaling': scaling_stats,
        'effects': effect_types
    }

print("Enriching abilities...\n")

total_relationships = 0

for champ in champions_to_process:
    champ_id = champ['id']
    champ_name = champ['name']
    
    print(f"\n{champ_name}:")
    
    # Process passive
    passive = champ.get('passive')
    if passive:
        result = enrich_ability(graph, champ_id, passive, 'Passive')
        rel_count = sum(len(v) for v in result.values())
        total_relationships += rel_count
        print(f"  [P] {passive.get('name')}: {rel_count} relationships")
        if result['cc']:
            print(f"      CC: {', '.join(result['cc'])}")
    
    # Process spells
    spells = champ.get('spells', [])
    for spell in spells:
        slot = spell.get('spellKey', '').upper()
        result = enrich_ability(graph, champ_id, spell, slot)
        rel_count = sum(len(v) for v in result.values())
        total_relationships += rel_count
        
        # Print interesting info
        info_parts = []
        if result['damage']:
            info_parts.append(f"Dmg: {','.join(result['damage'])}")
        if result['cc']:
            info_parts.append(f"CC: {','.join(result['cc'])}")
        if result['effects']:
            info_parts.append(f"FX: {','.join(result['effects'][:2])}")  # First 2 effects
        
        info_str = ' | '.join(info_parts) if info_parts else 'no special effects'
        print(f"  [{slot}] {spell.get('name')}: {info_str}")

print(f"\n\n🎉 Created {total_relationships} ability relationships!")
# Out:
# Enriching abilities...
#
#
# Annie:
#   [P] Pyromania: 1 relationships
#       CC: Stun
#   [Q] Disintegrate: Dmg: Magic
#   [W] Incinerate: Dmg: Magic
#   [E] Molten Shield: Dmg: Magic | FX: Shield,Movement
#   [R] Summon: Tibbers: Dmg: Magic | CC: Stun | FX: Movement,AttackSpeed
#
# Olaf:
#   [P] Berserker Rage: 4 relationships
#   [Q] Undertow: Dmg: Physical | CC: Slow,Grounded | FX: Movement
#   [W] Tough It Out: FX: Shield,Heal
#   [E] Reckless Swing: Dmg: True | FX: Heal
#   [R] Ragnarok: FX: Movement
#
# Galio:
#   [P] Colossal Smash: 1 relationships
#   [Q] Winds of War: Dmg: Magic | FX: Heal
#   [W] Shield of Durand: Dmg: Magic,Physical | CC: Taunt,Slow | FX: Shield
#   [E] Justice Punch: Dmg: Magic | CC: Knockup | FX: Dash
#   [R] Hero's Entrance: Dmg: Magic | CC: Stun,Knockup | FX: Shield
#
# Twisted Fate:
#   [P] Loaded Dice: 0 relationships
#   [Q] Wild Cards: Dmg: Magic
#   [W] Pick a Card: Dmg: Magic | CC: Stun,Slow
#   [E] Stacked Deck: Dmg: Magic | FX: AttackSpeed
#   [R] Destiny: FX: Blink
#
# Xin Zhao:
#   [P] Determination: 1 relationships
#   [Q] Three Talon Strike: Dmg: Physical | CC: Knockup
#   [W] Wind Becomes Lightning: Dmg: Physical | CC: Slow | FX: Stealth
#   [E] Audacious Charge: Dmg: Magic | CC: Slow | FX: AttackSpeed
#   [R] Crescent Guard: Dmg: Physical | CC: Knockback | FX: Heal
#
# Urgot:
#   [P] Echoing Flames: 1 relationships
#   [Q] Corrosive Charge: Dmg: Physical | CC: Slow
#   [W] Purge: Dmg: Physical | CC: Slow | FX: Movement
#   [E] Disdain: Dmg: Physical | CC: Stun | FX: Shield
#   [R] Fear Beyond Death: Dmg: Physical | CC: Fear,Slow,Suppress | FX: Heal
#
# LeBlanc:
#   [P] Mirror Image: 2 relationships
#   [Q] Sigil of Malice: Dmg: Magic
#   [W] Distortion: Dmg: Magic | FX: Dash
#   [E] Ethereal Chains: Dmg: Magic | CC: Root
#   [R] Mimic: Dmg: Magic | CC: Root
#
# Vladimir:
#   [P] Crimson Pact: 3 relationships
#   [Q] Transfusion: Dmg: Magic | FX: Heal,Movement
#   [W] Sanguine Pool: Dmg: Magic | CC: Slow | FX: Heal,Movement
#   [E] Tides of Blood: Dmg: Magic | CC: Slow | FX: Heal
#   [R] Hemoplague: Dmg: Magic | FX: Heal
#
# Fiddlesticks:
#   [P] A Harmless Scarecrow: 0 relationships
#   [Q] Terrify: Dmg: Magic | CC: Fear | FX: Heal
#   [W] Bountiful Harvest: Dmg: Magic | FX: Heal
#   [E] Reap: Dmg: Magic | CC: Slow,Silence
#   [R] Crowstorm: Dmg: Magic | FX: Blink
#
# Kayle:
#   [P] Divine Ascent: 3 relationships
#   [Q] Radiant Blast: Dmg: Magic | CC: Slow
#   [W] Celestial Blessing: FX: Heal,Movement
#   [E] Starfire Spellblade: Dmg: Magic | FX: Heal
#   [R] Divine Judgment: Dmg: Magic
#
# Master Yi:
#   [P] Double Strike: 0 relationships
#   [Q] Alpha Strike: Dmg: Physical | CC: Blind | FX: Blink
#   [W] Meditate: FX: Heal
#   [E] Wuju Style: Dmg: True
#   [R] Highlander: CC: Slow | FX: Movement,AttackSpeed
#
# Alistar:
#   [P] Triumphant Roar: 2 relationships
#       CC: Stun
#   [Q] Pulverize: Dmg: Magic | CC: Knockup,Grounded
#   [W] Headbutt: Dmg: Magic
#   [E] Trample: Dmg: Magic | CC: Stun,Grounded
#   [R] Unbreakable Will: no special effects
#
# Ryze:
#   [P] Arcane Mastery: 1 relationships
#   [Q] Overload: Dmg: Magic | FX: Movement
#   [W] Rune Prison: Dmg: Magic | CC: Root,Slow
#   [E] Spell Flux: Dmg: Magic
#   [R] Realm Warp: FX: Blink
#
# Sion:
#   [P] Glory in Death: 2 relationships
#   [Q] Decimating Smash: Dmg: Physical | CC: Stun,Slow
#   [W] Soul Furnace: Dmg: Magic | FX: Shield,Heal
#   [E] Roar of the Slayer: Dmg: Magic | CC: Slow
#   [R] Unstoppable Onslaught: Dmg: Physical | CC: Stun,Slow
#
# Sivir:
#   [P] Fleet of Foot: 1 relationships
#   [Q] Boomerang Blade: Dmg: Physical
#   [W] Ricochet: Dmg: Physical | FX: AttackSpeed
#   [E] Spell Shield: FX: Heal,Movement
#   [R] On The Hunt: FX: Movement
#
# Soraka:
#   [P] Salvation: 1 relationships
#   [Q] Starcall: Dmg: Magic | CC: Slow | FX: Heal,Movement
#   [W] Astral Infusion: FX: Heal
#   [E] Equinox: Dmg: Magic | CC: Root,Silence
#   [R] Wish: FX: Heal
#
# Teemo:
#   [P] Guerrilla Warfare: 3 relationships
#   [Q] Blinding Dart: Dmg: Magic | CC: Blind
#   [W] Move Quick: FX: Movement
#   [E] Toxic Shot: Dmg: Magic
#   [R] Noxious Trap: Dmg: Magic | CC: Slow | FX: Stealth
#
# Tristana:
#   [P] Draw a Bead: 0 relationships
#   [Q] Rapid Fire: FX: AttackSpeed
#   [W] Rocket Jump: Dmg: Magic | CC: Slow,Grounded
#   [E] Explosive Charge: Dmg: Magic,Physical
#   [R] Buster Shot: Dmg: Magic | CC: Stun,Knockback
#
# Warwick:
#   [P] Eternal Hunger: 2 relationships
#   [Q] Jaws of the Beast: Dmg: Magic | FX: Heal
#   [W] Blood Hunt: FX: Heal,Movement
#   [E] Primal Howl: CC: Fear
#   [R] Infinite Duress: Dmg: Magic | CC: Suppress | FX: Heal,Movement
#
# Nunu & Willump:
#   [P] Call of the Freljord: 3 relationships
#   [Q] Consume: Dmg: Magic,True | FX: Heal
#   [W] Biggest Snowball Ever!: Dmg: Magic | CC: Knockup,Slow
#   [E] Snowball Barrage: Dmg: Magic | CC: Root,Slow
#   [R] Absolute Zero: Dmg: Magic | CC: Slow | FX: Shield
#
# Miss Fortune:
#   [P] Love Tap: 1 relationships
#   [Q] Double Up: Dmg: Physical
#   [W] Strut: FX: Movement,AttackSpeed
#   [E] Make It Rain: Dmg: Magic | CC: Slow
#   [R] Bullet Time: Dmg: Physical
#
# Ashe:
#   [P] Frost Shot: 2 relationships
#       CC: Slow
#   [Q] Ranger's Focus: Dmg: Physical | FX: AttackSpeed
#   [W] Volley: Dmg: Physical
#   [E] Hawkshot: no special effects
#   [R] Enchanted Crystal Arrow: Dmg: Magic | CC: Stun,Slow
#
# Tryndamere:
#   [P] Battle Fury: 1 relationships
#   [Q] Bloodlust: FX: Heal
#   [W] Mocking Shout: CC: Slow | FX: Movement
#   [E] Spinning Slash: Dmg: Physical
#   [R] Undying Rage: FX: Heal
#
# Jax:
#   [P] Relentless Assault: 2 relationships
#   [Q] Leap Strike: Dmg: Physical
#   [W] Empower: Dmg: Magic
#   [E] Counter Strike: Dmg: Magic | CC: Stun | FX: Heal
#   [R] Grandmaster-at-Arms: Dmg: Magic
#
# Morgana:
#   [P] Soul Siphon: 1 relationships
#   [Q] Dark Binding: Dmg: Magic | CC: Root
#   [W] Tormented Shadow: Dmg: Magic | CC: Grounded | FX: Heal
#   [E] Black Shield: FX: Shield
#   [R] Soul Shackles: Dmg: Magic | CC: Stun,Slow,Grounded | FX: Movement
#
# Zilean:
#   [P] Time In A Bottle: 0 relationships
#   [Q] Time Bomb: Dmg: Magic | CC: Stun
#   [W] Rewind: no special effects
#   [E] Time Warp: CC: Slow | FX: Movement
#   [R] Chronoshift: FX: Heal,Blink
#
# Singed:
#   [P] Noxious Slipstream: 1 relationships
#   [Q] Poison Trail: Dmg: Magic
#   [W] Mega Adhesive: CC: Slow,Grounded
#   [E] Fling: Dmg: Magic | CC: Root | FX: Heal
#   [R] Insanity Potion: FX: Heal,Movement
#
# Evelynn:
#   [P] Demon Shade: 1 relationships
#   [Q] Hate Spike: Dmg: Magic
#   [W] Allure: Dmg: Magic | CC: Charm,Slow
#   [E] Whiplash: Dmg: Magic | FX: Heal,Dash
#   [R] Last Caress: Dmg: Magic | FX: Heal,Blink
#
# Twitch:
#   [P] Deadly Venom: 1 relationships
#   [Q] Ambush: FX: Stealth,Movement
#   [W] Venom Cask: CC: Slow
#   [E] Contaminate: Dmg: Magic,Physical
#   [R] Spray and Pray: no special effects
#
# Karthus:
#   [P] Death Defied: 0 relationships
#   [Q] Lay Waste: Dmg: Magic
#   [W] Wall of Pain: CC: Slow | FX: Movement
#   [E] Defile: Dmg: Magic
#   [R] Requiem: Dmg: Magic
#
# Cho'Gath:
#   [P] Carnivore: 1 relationships
#   [Q] Rupture: Dmg: Magic | CC: Knockup,Slow,Grounded
#   [W] Feral Scream: Dmg: Magic
#   [E] Vorpal Spikes: Dmg: Magic | CC: Slow | FX: Heal
#   [R] Feast: Dmg: True | FX: Heal
#
# Amumu:
#   [P] Cursed Touch: 2 relationships
#   [Q] Bandage Toss: Dmg: Magic | CC: Stun
#   [W] Despair: Dmg: Magic | FX: Heal
#   [E] Tantrum: Dmg: Magic,Physical
#   [R] Curse of the Sad Mummy: Dmg: Magic | CC: Stun
#
# Rammus:
#   [P] Spiked Shell: 3 relationships
#   [Q] Powerball: Dmg: Magic | CC: Knockback,Slow | FX: Movement
#   [W] Defensive Ball Curl: Dmg: Magic
#   [E] Frenzying Taunt: Dmg: Magic | CC: Taunt
#   [R] Soaring Slam: Dmg: Magic | CC: Knockup,Slow | FX: Movement
#
# Anivia:
#   [P] Rebirth: 1 relationships
#   [Q] Flash Frost: Dmg: Magic | CC: Stun,Slow
#   [W] Crystallize: no special effects
#   [E] Frostbite: Dmg: Magic
#   [R] Glacial Storm: Dmg: Magic | CC: Slow
#
# Shaco:
#   [P] Backstab: 0 relationships
#   [Q] Deceive: Dmg: Physical | FX: Blink,Stealth
#   [W] Jack In The Box: Dmg: Magic | CC: Fear | FX: Stealth
#   [E] Two-Shiv Poison: Dmg: Magic | CC: Slow | FX: Heal,Movement
#   [R] Hallucinate: Dmg: Magic | CC: Fear
#
# Dr. Mundo:
#   [P] Goes Where He Pleases: 1 relationships
#   [Q] Infected Bonesaw: Dmg: Magic | CC: Slow | FX: Heal
#   [W] Heart Zapper: Dmg: Magic | FX: Heal
#   [E] Blunt Force Trauma: Dmg: Physical | FX: Heal
#   [R] Maximum Dosage: FX: Heal,Movement
#
# Sona:
#   [P] Power Chord: 1 relationships
#   [Q] Hymn of Valor: Dmg: Magic
#   [W] Aria of Perseverance: Dmg: Magic | FX: Shield,Heal
#   [E] Song of Celerity: CC: Slow | FX: Movement
#   [R] Crescendo: Dmg: Magic | CC: Stun
#
# Kassadin:
#   [P] Void Stone: 1 relationships
#   [Q] Null Sphere: Dmg: Magic | FX: Shield
#   [W] Nether Blade: Dmg: Magic
#   [E] Force Pulse: Dmg: Magic | CC: Slow
#   [R] Riftwalk: Dmg: Magic | FX: Blink
#
# Irelia:
#   [P] Ionian Fervor: 2 relationships
#   [Q] Bladesurge: Dmg: Physical | FX: Heal,Dash
#   [W] Defiant Dance: Dmg: Magic,Physical
#   [E] Flawless Duet: Dmg: Magic | CC: Stun,Grounded
#   [R] Vanguard's Edge: Dmg: Magic | CC: Slow
#
# Janna:
#   [P] Tailwind: 2 relationships
#   [Q] Howling Gale: Dmg: Magic | CC: Knockup,Knockback
#   [W] Zephyr: Dmg: Magic | CC: Slow | FX: Movement
#   [E] Eye Of The Storm: FX: Shield
#   [R] Monsoon: CC: Knockback | FX: Heal
#
# Gangplank:
#   [P] Trial by Fire: 0 relationships
#   [Q] Parrrley: no special effects
#   [W] Remove Scurvy: FX: Heal
#   [E] Powder Keg: Dmg: Physical | CC: Slow | FX: Heal
#   [R] Cannon Barrage: Dmg: Magic,True | CC: Slow | FX: Movement
#
# Corki:
#   [P] Hextech Munitions: 2 relationships
#   [Q] Phosphorus Bomb: Dmg: Magic
#   [W] Valkyrie: Dmg: Magic
#   [E] Gatling Gun: Dmg: Physical
#   [R] Missile Barrage: Dmg: Physical
#
# Karma:
#   [P] Gathering Fire: 0 relationships
#   [Q] Inner Flame: Dmg: Magic | CC: Slow
#   [W] Focused Resolve: Dmg: Magic | CC: Root | FX: Heal
#   [E] Inspire: FX: Shield,Movement
#   [R] Mantra: Dmg: Magic | CC: Root,Slow | FX: Shield,Heal
#
# Taric:
#   [P] Bravado: 1 relationships
#   [Q] Starlight's Touch: FX: Heal
#   [W] Bastion: FX: Shield,Heal
#   [E] Dazzle: Dmg: Magic | CC: Stun
#   [R] Cosmic Radiance: no special effects
#
# Veigar:
#   [P] Phenomenal Evil Power: 1 relationships
#   [Q] Baleful Strike: Dmg: Magic
#   [W] Dark Matter: Dmg: Magic
#   [E] Event Horizon: CC: Stun
#   [R] Primordial Burst: Dmg: Magic | FX: Heal
#
# Trundle:
#   [P] King's Tribute: 2 relationships
#   [Q] Chomp: Dmg: Physical | CC: Slow
#   [W] Frozen Domain: FX: Heal,Movement
#   [E] Pillar of Ice: CC: Knockback,Slow
#   [R] Subjugate: Dmg: Magic | FX: Heal
#
# Swain:
#   [P] Ravenous Flock: 2 relationships
#   [Q] Death's Hand: Dmg: Magic
#   [W] Vision of Empire: Dmg: Magic | CC: Slow
#   [E] Nevermove: Dmg: Magic | CC: Root
#   [R] Demonic Ascension: Dmg: Magic | CC: Slow | FX: Heal
#
# Caitlyn:
#   [P] Headshot: 1 relationships
#   [Q] Piltover Peacemaker: Dmg: Physical
#   [W] Yordle Snap Trap: Dmg: Physical | CC: Root
#   [E] 90 Caliber Net: Dmg: Magic | CC: Slow
#   [R] Ace in the Hole: Dmg: Physical
#
# Blitzcrank:
#   [P] Mana Barrier: 2 relationships
#   [Q] Rocket Grab: Dmg: Magic
#   [W] Overdrive: CC: Slow | FX: Movement,AttackSpeed
#   [E] Power Fist: Dmg: Physical | CC: Knockup
#   [R] Static Field: Dmg: Magic | CC: Silence | FX: Shield
#
# Malphite:
#   [P] Granite Shield: 3 relationships
#   [Q] Seismic Shard: Dmg: Magic | CC: Slow,Grounded | FX: Movement
#   [W] Thunderclap: Dmg: Physical | FX: Shield
#   [E] Ground Slam: Dmg: Magic | CC: Grounded | FX: AttackSpeed
#   [R] Unstoppable Force: Dmg: Magic | CC: Knockup | FX: Dash
#
# Katarina:
#   [P] Voracity: 1 relationships
#   [Q] Bouncing Blade: Dmg: Magic | CC: Grounded
#   [W] Preparation: FX: Movement
#   [E] Shunpo: Dmg: Magic | FX: Blink
#   [R] Death Lotus: Dmg: Magic,Physical
#
# Nocturne:
#   [P] Umbra Blades: 2 relationships
#   [Q] Duskbringer: Dmg: Physical | FX: Movement
#   [W] Shroud of Darkness: FX: AttackSpeed
#   [E] Unspeakable Horror: Dmg: Magic | CC: Fear | FX: Movement
#   [R] Paranoia: Dmg: Physical
#
# Maokai:
#   [P] Sap Magic: 1 relationships
#   [Q] Bramble Smash: Dmg: Magic | CC: Knockback,Slow,Grounded | FX: Heal
#   [W] Twisted Advance: Dmg: Magic | CC: Root | FX: Dash
#   [E] Sapling Toss: Dmg: Magic | CC: Slow
#   [R] Nature's Grasp: Dmg: Magic | CC: Root,Slow | FX: Movement
#
# Renekton:
#   [P] Reign of Anger: 0 relationships
#   [Q] Cull the Meek: Dmg: Physical | FX: Heal
#   [W] Ruthless Predator: Dmg: Physical | CC: Stun | FX: Shield
#   [E] Slice and Dice: Dmg: Physical | FX: Dash
#   [R] Dominus: Dmg: Magic | FX: Heal
#
# Jarvan IV:
#   [P] Martial Cadence: 2 relationships
#   [Q] Dragon Strike: Dmg: Physical | CC: Knockup
#   [W] Golden Aegis: CC: Slow | FX: Shield
#   [E] Demacian Standard: Dmg: Magic | CC: Grounded | FX: AttackSpeed
#   [R] Cataclysm: Dmg: Physical
#
# Elise:
#   [P] Spider Queen: 2 relationships
#   [Q] Neurotoxin / Venomous Bite: Dmg: Magic | FX: Heal
#   [W] Volatile Spiderling / Skittering Frenzy: Dmg: Magic | FX: AttackSpeed
#   [E] Cocoon / Rappel: CC: Stun | FX: Heal,Stealth
#   [R] Spider Form: FX: Movement
#
# Orianna:
#   [P] Clockwork Windup: 1 relationships
#   [Q] Command: Attack: Dmg: Magic
#   [W] Command: Dissonance: Dmg: Magic | CC: Slow | FX: Movement
#   [E] Command: Protect: Dmg: Magic | FX: Shield
#   [R] Command: Shockwave: Dmg: Magic
#
# Wukong:
#   [P] Stone Skin: 3 relationships
#   [Q] Crushing Blow: Dmg: Physical
#   [W] Warrior Trickster: FX: Dash,Stealth
#   [E] Nimbus Strike: Dmg: Magic | FX: Dash,AttackSpeed
#   [R] Cyclone: Dmg: Physical | CC: Knockup | FX: Heal,Movement
#
# Brand:
#   [P] Blaze: 0 relationships
#   [Q] Sear: Dmg: Magic | CC: Stun
#   [W] Pillar of Flame: Dmg: Magic
#   [E] Conflagration: Dmg: Magic
#   [R] Pyroclasm: Dmg: Magic | CC: Slow
#
# Lee Sin:
#   [P] Flurry: 2 relationships
#   [Q] Sonic Wave / Resonating Strike: Dmg: Physical | FX: Heal,Dash
#   [W] Safeguard / Iron Will: FX: Shield,Dash
#   [E] Tempest / Cripple: Dmg: Magic | CC: Slow,Grounded | FX: Movement
#   [R] Dragon's Rage: Dmg: Physical | CC: Knockback | FX: Heal
#
# Vayne:
#   [P] Night Hunter: 1 relationships
#   [Q] Tumble: Dmg: Physical
#   [W] Silver Bolts: Dmg: True | FX: Heal
#   [E] Condemn: Dmg: Physical | CC: Stun,Knockback
#   [R] Final Hour: Dmg: Physical | FX: Stealth,Movement
#
# Rumble:
#   [P] Junkyard Titan: 2 relationships
#   [Q] Flamespitter: Dmg: Magic | FX: Heal
#   [W] Scrap Shield: FX: Shield,Movement
#   [E] Electro Harpoon: Dmg: Magic | CC: Slow | FX: Movement
#   [R] The Equalizer: Dmg: Magic | CC: Slow
#
# Cassiopeia:
#   [P] Serpentine Grace: 1 relationships
#   [Q] Noxious Blast: Dmg: Magic | FX: Movement
#   [W] Miasma: Dmg: Magic | CC: Slow,Grounded
#   [E] Twin Fang: Dmg: Magic | FX: Heal
#   [R] Petrifying Gaze: Dmg: Magic | CC: Stun,Slow
#
# Skarner:
#   [P] Threads of Vibration: 3 relationships
#   [Q] Shattered Earth / Upheaval: Dmg: Physical | CC: Slow,Grounded | FX: Heal,AttackSpeed
#   [W] Seismic Bastion: Dmg: Magic | CC: Slow | FX: Shield
#   [E] Ixtal's Impact: Dmg: Physical | CC: Stun
#   [R] Impale: Dmg: Magic | CC: Suppress | FX: Movement
#
# Heimerdinger:
#   [P] Hextech Affinity: 1 relationships
#   [Q] H-28 G Evolution Turret: CC: Slow
#   [W] Hextech Micro-Rockets: Dmg: Magic
#   [E] CH-2 Electron Storm Grenade: Dmg: Magic | CC: Stun,Slow
#   [R] UPGRADE!!!: Dmg: Magic | CC: Stun,Slow
#
# Nasus:
#   [P] Soul Eater: 1 relationships
#   [Q] Siphoning Strike: Dmg: Physical
#   [W] Wither: CC: Slow | FX: Movement,AttackSpeed
#   [E] Spirit Fire: Dmg: Magic
#   [R] Fury of the Sands: Dmg: Magic | FX: Heal
#
# Nidalee:
#   [P] Prowl: 1 relationships
#   [Q] Javelin Toss / Takedown: Dmg: Magic
#   [W] Bushwhack / Pounce: Dmg: Magic | FX: Stealth
#   [E] Primal Surge / Swipe: FX: Heal,AttackSpeed
#   [R] Aspect Of The Cougar: no special effects
#
# Udyr:
#   [P] Bridge Between: 2 relationships
#   [Q] Wilding Claw: Dmg: Magic,Physical | FX: Heal,AttackSpeed
#   [W] Iron Mantle: FX: Shield,Heal
#   [E] Blazing Stampede: CC: Stun | FX: Dash,Movement
#   [R] Wingborne Storm: Dmg: Magic | CC: Slow | FX: Heal
#
# Poppy:
#   [P] Iron Ambassador: 1 relationships
#   [Q] Hammer Shock: Dmg: Physical | CC: Slow,Grounded | FX: Heal
#   [W] Steadfast Presence: Dmg: Magic | CC: Slow,Grounded | FX: Heal,Dash
#   [E] Heroic Charge: Dmg: Physical | CC: Stun | FX: Dash
#   [R] Keeper's Verdict: Dmg: Physical | CC: Knockup,Knockback,Slow,Grounded
#
# Gragas:
#   [P] Happy Hour: 1 relationships
#   [Q] Barrel Roll: Dmg: Magic | CC: Slow | FX: Movement
#   [W] Drunken Rage: Dmg: Magic | FX: Heal
#   [E] Body Slam: Dmg: Magic | CC: Stun,Knockup
#   [R] Explosive Cask: Dmg: Magic | CC: Knockback
#
# Pantheon:
#   [P] Mortal Will: 0 relationships
#   [Q] Comet Spear: Dmg: Physical | FX: Heal
#   [W] Shield Vault: Dmg: Physical | CC: Stun | FX: Heal,Dash
#   [E] Aegis Assault: Dmg: Physical | FX: Shield,Movement
#   [R] Grand Starfall: Dmg: Magic,Physical | CC: Slow
#
# Ezreal:
#   [P] Rising Spell Force: 2 relationships
#   [Q] Mystic Shot: Dmg: Physical
#   [W] Essence Flux: Dmg: Magic
#   [E] Arcane Shift: Dmg: Magic | FX: Blink
#   [R] Trueshot Barrage: Dmg: Magic
#
# Mordekaiser:
#   [P] Darkness Rise: 1 relationships
#   [Q] Obliterate: Dmg: Magic | CC: Grounded
#   [W] Indestructible: FX: Shield,Heal
#   [E] Death's Grasp: Dmg: Magic
#   [R] Realm of Death: no special effects
#
# Yorick:
#   [P] Shepherd of Souls: 0 relationships
#   [Q] Last Rites: Dmg: Physical | FX: Heal
#   [W] Dark Procession: FX: Heal
#   [E] Mourning Mist: Dmg: Magic | CC: Slow | FX: Heal,Movement
#   [R] Eulogy of the Isles: Dmg: Magic | FX: Heal
#
# Akali:
#   [P] Assassin's Mark: 0 relationships
#   [Q] Five Point Strike: Dmg: Magic | CC: Slow
#   [W] Twilight Shroud: FX: Stealth,Movement
#   [E] Shuriken Flip: Dmg: Magic | FX: Dash
#   [R] Perfect Execution: Dmg: Magic | FX: Heal,Dash
#
# Kennen:
#   [P] Mark of the Storm: 1 relationships
#       CC: Stun
#   [Q] Thundering Shuriken: Dmg: Magic
#   [W] Electrical Surge: Dmg: Magic
#   [E] Lightning Rush: Dmg: Magic | FX: Movement,AttackSpeed
#   [R] Slicing Maelstrom: Dmg: Magic
#
# Garen:
#   [P] Perseverance: 1 relationships
#   [Q] Decisive Strike: Dmg: Physical | CC: Slow,Silence | FX: Movement
#   [W] Courage: CC: Slow | FX: Shield
#   [E] Judgment: Dmg: Physical
#   [R] Demacian Justice: Dmg: True | FX: Heal
#
# Leona:
#   [P] Sunlight: 1 relationships
#   [Q] Shield of Daybreak: Dmg: Magic | CC: Stun | FX: Shield
#   [W] Eclipse: Dmg: Magic | FX: Shield
#   [E] Zenith Blade: Dmg: Magic | CC: Root | FX: Dash
#   [R] Solar Flare: Dmg: Magic | CC: Stun,Slow
#
# Malzahar:
#   [P] Void Shift: 0 relationships
#   [Q] Call of the Void: Dmg: Magic | CC: Silence
#   [W] Void Swarm: Dmg: Magic
#   [E] Malefic Visions: Dmg: Magic | FX: Heal
#   [R] Nether Grasp: Dmg: Magic | CC: Suppress | FX: Heal
#
# Talon:
#   [P] Blade's End: 0 relationships
#   [Q] Noxian Diplomacy: Dmg: Physical | FX: Heal
#   [W] Rake: Dmg: Physical | CC: Slow
#   [E] Assassin's Path: FX: Dash
#   [R] Shadow Assault: Dmg: Physical | FX: Stealth,Movement
#
# Riven:
#   [P] Runic Blade: 0 relationships
#   [Q] Broken Wings: Dmg: Physical | CC: Knockup,Knockback | FX: Dash
#   [W] Ki Burst: Dmg: Physical | CC: Stun
#   [E] Valor: FX: Shield,Dash
#   [R] Blade of the Exile: Dmg: Physical | FX: Heal
#
# Kog'Maw:
#   [P] Icathian Surprise: 1 relationships
#   [Q] Caustic Spittle: Dmg: Magic | FX: AttackSpeed
#   [W] Bio-Arcane Barrage: Dmg: Magic | FX: Heal
#   [E] Void Ooze: Dmg: Magic | CC: Slow
#   [R] Living Artillery: Dmg: Magic | FX: Heal,Stealth
#
# Shen:
#   [P] Ki Barrier: 1 relationships
#   [Q] Twilight Assault: Dmg: Magic | CC: Slow | FX: Heal,AttackSpeed
#   [W] Spirit's Refuge: no special effects
#   [E] Shadow Dash: Dmg: Physical | CC: Taunt | FX: Dash
#   [R] Stand United: FX: Shield,Heal
#
# Lux:
#   [P] Illumination: 1 relationships
#   [Q] Light Binding: Dmg: Magic | CC: Root
#   [W] Prismatic Barrier: FX: Shield
#   [E] Lucent Singularity: Dmg: Magic | CC: Slow
#   [R] Final Spark: Dmg: Magic
#
# Xerath:
#   [P] Mana Surge: 0 relationships
#   [Q] Arcanopulse: Dmg: Magic | CC: Slow
#   [W] Eye of Destruction: Dmg: Magic | CC: Slow
#   [E] Shocking Orb: Dmg: Magic | CC: Stun
#   [R] Rite of the Arcane: Dmg: Magic
#
# Shyvana:
#   [P] Fury of the Dragonborn: 2 relationships
#   [Q] Twin Bite: Dmg: Physical | FX: AttackSpeed
#   [W] Burnout: Dmg: Magic | FX: Movement
#   [E] Flame Breath: Dmg: Magic | FX: Heal
#   [R] Dragon's Descent: Dmg: Magic | FX: Heal
#
# Ahri:
#   [P] Essence Theft: 1 relationships
#   [Q] Orb of Deception: Dmg: Magic,True
#   [W] Fox-Fire: Dmg: Magic | FX: Movement
#   [E] Charm: Dmg: Magic | CC: Charm
#   [R] Spirit Rush: Dmg: Magic | FX: Dash
#
# Graves:
#   [P] New Destiny: 0 relationships
#   [Q] End of the Line: Dmg: Physical
#   [W] Smoke Screen: Dmg: Magic | CC: Slow | FX: Movement
#   [E] Quickdraw: FX: Dash
#   [R] Collateral Damage: Dmg: Physical
#
# Fizz:
#   [P] Nimble Fighter: 0 relationships
#   [Q] Urchin Strike: Dmg: Magic,Physical | FX: Dash
#   [W] Seastone Trident: Dmg: Magic
#   [E] Playful / Trickster: Dmg: Magic | CC: Slow,Grounded | FX: Dash
#   [R] Chum the Waters: Dmg: Magic | CC: Knockup,Knockback,Slow,Grounded
#
# Volibear:
#   [P] The Relentless Storm: 3 relationships
#   [Q] Thundering Smash: Dmg: Physical | CC: Stun | FX: Movement
#   [W] Frenzied Maul: Dmg: Physical | FX: Heal
#   [E] Sky Splitter: Dmg: Magic | CC: Slow | FX: Shield,Heal
#   [R] Stormbringer: Dmg: Physical | CC: Slow | FX: Heal
#
# Rengar:
#   [P] Unseen Predator: 1 relationships
#   [Q] Savagery: Dmg: Physical | FX: AttackSpeed
#   [W] Battle Roar: Dmg: Magic | FX: Heal
#   [E] Bola Strike: Dmg: Physical | CC: Root,Slow
#   [R] Thrill of the Hunt: Dmg: Physical | FX: Stealth,Movement
#
# Varus:
#   [P] Living Vengeance: 2 relationships
#   [Q] Piercing Arrow: Dmg: Physical | CC: Slow
#   [W] Blighted Quiver: Dmg: Magic | FX: Heal
#   [E] Hail of Arrows: Dmg: Physical | CC: Slow,Grounded | FX: Heal,Movement
#   [R] Chain of Corruption: Dmg: Magic | CC: Root
#
# Nautilus:
#   [P] Staggering Blow: 2 relationships
#       CC: Root
#   [Q] Dredge Line: Dmg: Magic | CC: Stun
#   [W] Titan's Wrath: Dmg: Magic | FX: Shield
#   [E] Riptide: Dmg: Magic | CC: Slow
#   [R] Depth Charge: Dmg: Magic | CC: Stun
#
# Viktor:
#   [P] Glorious Evolution: 0 relationships
#   [Q] Siphon Power: Dmg: Magic | FX: Shield,Movement
#   [W] Gravity Field: CC: Stun,Slow
#   [E] Hextech Ray: Dmg: Magic
#   [R] Arcane Storm: Dmg: Magic
#
# Sejuani:
#   [P] Fury of the North: 5 relationships
#       CC: Stun, Slow
#   [Q] Arctic Assault: Dmg: Magic
#   [W] Winter's Wrath: Dmg: Physical | CC: Knockback,Slow
#   [E] Permafrost: Dmg: Magic | CC: Stun
#   [R] Glacial Prison: Dmg: Magic | CC: Stun,Slow
#
# Fiora:
#   [P] Duelist's Dance: 2 relationships
#   [Q] Lunge: Dmg: Physical
#   [W] Riposte: Dmg: Magic | CC: Stun,Slow | FX: Movement,AttackSpeed
#   [E] Bladework: Dmg: Physical | CC: Slow | FX: AttackSpeed
#   [R] Grand Challenge: Dmg: True | FX: Heal,Movement
#
# Ziggs:
#   [P] Short Fuse: 1 relationships
#   [Q] Bouncing Bomb: Dmg: Magic
#   [W] Satchel Charge: Dmg: Magic | FX: Heal
#   [E] Hexplosive Minefield: Dmg: Magic | CC: Slow
#   [R] Mega Inferno Bomb: Dmg: Magic
#
# Lulu:
#   [P] Pix, Faerie Companion: 0 relationships
#   [Q] Glitterlance: Dmg: Magic | CC: Slow
#   [W] Whimsy: FX: Movement,AttackSpeed
#   [E] Help, Pix!: Dmg: Magic | FX: Shield
#   [R] Wild Growth: CC: Knockup,Slow | FX: Heal
#
# Draven:
#   [P] League of Draven: 0 relationships
#   [Q] Spinning Axe: Dmg: Physical
#   [W] Blood Rush: FX: Movement,AttackSpeed
#   [E] Stand Aside: Dmg: Physical | CC: Knockback,Slow
#   [R] Whirling Death: Dmg: Physical | CC: Slow | FX: Heal
#
# Hecarim:
#   [P] Warpath: 2 relationships
#   [Q] Rampage: Dmg: Physical
#   [W] Spirit of Dread: Dmg: Magic | FX: Heal
#   [E] Devastating Charge: Dmg: Physical | CC: Knockback | FX: Movement
#   [R] Onslaught of Shadows: Dmg: Magic | CC: Fear
#
# Kha'Zix:
#   [P] Unseen Threat: 2 relationships
#       CC: Slow
#   [Q] Taste Their Fear: Dmg: Physical | CC: Fear
#   [W] Void Spike: Dmg: Physical | CC: Slow | FX: Heal
#   [E] Leap: Dmg: Physical
#   [R] Void Assault: CC: Fear,Slow | FX: Stealth,Movement
#
# Darius:
#   [P] Hemorrhage: 2 relationships
#   [Q] Decimate: Dmg: Physical | FX: Heal
#   [W] Crippling Strike: Dmg: Physical | CC: Slow | FX: Movement
#   [E] Apprehend: Dmg: Physical | CC: Knockup,Slow
#   [R] Noxian Guillotine: Dmg: True
#
# Jayce:
#   [P] Hextech Capacitor: 1 relationships
#   [Q] To the Skies! / Shock Blast: Dmg: Physical | CC: Slow
#   [W] Lightning Field / Hyper Charge: Dmg: Magic | FX: AttackSpeed
#   [E] Thundering Blow / Acceleration Gate: Dmg: Magic | CC: Knockback | FX: Heal,Movement
#   [R] Mercury Cannon / Mercury Hammer: Dmg: Magic
#
# Lissandra:
#   [P] Iceborn Subjugation: 2 relationships
#       CC: Slow
#   [Q] Ice Shard: Dmg: Magic | CC: Slow | FX: Movement
#   [W] Ring of Frost: Dmg: Magic | CC: Root
#   [E] Glacial Path: Dmg: Magic | FX: Blink
#   [R] Frozen Tomb: Dmg: Magic | CC: Stun,Slow | FX: Heal,Movement
#
# Diana:
#   [P] Moonsilver Blade: 3 relationships
#   [Q] Crescent Strike: Dmg: Magic | FX: Stealth
#   [W] Pale Cascade: Dmg: Magic | FX: Shield
#   [E] Lunar Rush: Dmg: Magic | FX: Dash
#   [R] Moonfall: Dmg: Magic | CC: Slow
#
# Quinn:
#   [P] Harrier: 1 relationships
#   [Q] Blinding Assault: Dmg: Physical | CC: Disarm
#   [W] Heightened Senses: FX: Movement,AttackSpeed
#   [E] Vault: Dmg: Physical | CC: Slow | FX: Dash,Movement
#   [R] Behind Enemy Lines: Dmg: Physical | CC: Blind | FX: Movement
#
# Syndra:
#   [P] Transcendent: 3 relationships
#       CC: Slow
#   [Q] Dark Sphere: Dmg: Magic
#   [W] Force of Will: Dmg: Magic,True | CC: Slow | FX: Movement
#   [E] Scatter the Weak: Dmg: Magic | CC: Stun,Knockback,Slow
#   [R] Unleashed Power: Dmg: Magic | FX: Heal
#
# Aurelion Sol:
#   [P] Cosmic Creator: 0 relationships
#   [Q] Breath of Light: Dmg: Magic | FX: Heal
#   [W] Astral Flight: no special effects
#   [E] Singularity: Dmg: Magic | CC: Slow | FX: Heal
#   [R] Falling Star / The Skies Descend: Dmg: Magic | CC: Stun,Knockup,Slow
#
# Kayn:
#   [P] The Darkin Scythe: 1 relationships
#   [Q] Reaping Slash: Dmg: Physical | FX: Heal,Dash
#   [W] Blade's Reach: Dmg: Physical | CC: Knockup,Slow
#   [E] Shadow Step: CC: Slow | FX: Heal,Movement
#   [R] Umbral Trespass: Dmg: Physical | FX: Heal
#
# Zoe:
#   [P] More Sparkles!: 1 relationships
#   [Q] Paddle Star!: Dmg: Magic
#   [W] Spell Thief: Dmg: Magic | FX: Movement
#   [E] Sleepy Trouble Bubble: Dmg: Magic,True
#   [R] Portal Jump: FX: Blink
#
# Zyra:
#   [P] Garden of Thorns: 1 relationships
#       CC: Root
#   [Q] Deadly Spines: Dmg: Magic | CC: Grounded
#   [W] Rampant Growth: CC: Root
#   [E] Grasping Roots: Dmg: Magic | CC: Root,Slow,Grounded | FX: Movement
#   [R] Stranglethorns: Dmg: Magic | CC: Knockup | FX: Heal
#
# Kai'Sa:
#   [P] Second Skin: 1 relationships
#   [Q] Icathian Rain: Dmg: Physical
#   [W] Void Seeker: Dmg: Magic
#   [E] Supercharge: FX: Stealth,Movement
#   [R] Killer Instinct: FX: Shield,Dash
#
# Seraphine:
#   [P] Stage Presence: 1 relationships
#   [Q] High Note: Dmg: Magic | FX: Heal
#   [W] Surround Sound: FX: Shield,Heal
#   [E] Beat Drop: Dmg: Magic | CC: Stun,Root,Slow
#   [R] Encore: Dmg: Magic | CC: Charm
#
# Gnar:
#   [P] Rage Gene: 0 relationships
#   [Q] Boomerang Throw / Boulder Toss: Dmg: Physical | CC: Slow
#   [W] Hyper / Wallop: Dmg: Magic | CC: Stun | FX: Heal,Movement
#   [E] Hop / Crunch: Dmg: Physical | CC: Slow | FX: AttackSpeed
#   [R] GNAR!: Dmg: Physical | CC: Stun,Knockback,Slow | FX: Movement
#
# Zac:
#   [P] Cell Division: 4 relationships
#   [Q] Stretching Strikes: Dmg: Magic | CC: Knockup,Slow
#   [W] Unstable Matter: Dmg: Magic | FX: Heal
#   [E] Elastic Slingshot: Dmg: Magic | CC: Knockup,Grounded | FX: Dash
#   [R] Let's Bounce!: Dmg: Magic | CC: Knockup,Slow | FX: Movement
#
# Yasuo:
#   [P] Way of the Wanderer: 2 relationships
#   [Q] Steel Tempest: Dmg: Physical | CC: Knockup | FX: Dash
#   [W] Wind Wall: no special effects
#   [E] Sweeping Blade: Dmg: Magic | FX: Dash
#   [R] Last Breath: Dmg: Physical | FX: Blink
#
# Vel'Koz:
#   [P] Organic Deconstruction: 1 relationships
#   [Q] Plasma Fission: Dmg: Magic | CC: Slow
#   [W] Void Rift: Dmg: Magic
#   [E] Tectonic Disruption: Dmg: Magic | CC: Stun,Knockup
#   [R] Life Form Disintegration Ray: Dmg: Magic,True | CC: Slow
#
# Taliyah:
#   [P] Rock Surfing: 1 relationships
#   [Q] Threaded Volley: Dmg: Magic | CC: Stun,Slow,Grounded
#   [W] Seismic Shove: CC: Grounded
#   [E] Unraveled Earth: Dmg: Magic | CC: Stun,Slow | FX: Dash
#   [R] Weaver's Wall: no special effects
#
# Camille:
#   [P] Adaptive Defenses: 3 relationships
#   [Q] Precision Protocol: Dmg: Physical,True | FX: Movement
#   [W] Tactical Sweep: Dmg: Physical | CC: Slow | FX: Heal
#   [E] Hookshot: Dmg: Physical | CC: Stun,Knockup | FX: Dash,AttackSpeed
#   [R] The Hextech Ultimatum: Dmg: Magic | FX: Heal,Dash
#
# Akshan:
#   [P] Dirty Fighting: 2 relationships
#   [Q] Avengerang: Dmg: Physical | FX: Movement
#   [W] Going Rogue: FX: Movement
#   [E] Heroic Swing: Dmg: Physical
#   [R] Comeuppance: Dmg: Physical | FX: Heal
#
# Bel'Veth:
#   [P] Death in Lavender : 2 relationships
#   [Q] Void Surge: Dmg: Physical | FX: Dash,AttackSpeed
#   [W] Above and Below: Dmg: Magic | CC: Knockup,Slow,Grounded
#   [E] Royal Maelstrom: Dmg: Physical | CC: Root | FX: Heal,AttackSpeed
#   [R] Endless Banquet: Dmg: True | CC: Slow | FX: Heal,Movement
#
# Braum:
#   [P] Concussive Blows: 2 relationships
#       CC: Stun
#   [Q] Winter's Bite: Dmg: Magic | CC: Slow | FX: Shield
#   [W] Stand Behind Me: no special effects
#   [E] Unbreakable: FX: Shield,Movement
#   [R] Glacial Fissure: Dmg: Magic | CC: Knockup,Slow,Grounded
#
# Jhin:
#   [P] Whisper: 2 relationships
#   [Q] Dancing Grenade: Dmg: Physical
#   [W] Deadly Flourish: Dmg: Physical | CC: Root | FX: Movement
#   [E] Captive Audience: Dmg: Magic | CC: Slow | FX: Stealth
#   [R] Curtain Call: Dmg: Physical | CC: Slow | FX: Heal
#
# Kindred:
#   [P] Mark of the Kindred: 0 relationships
#   [Q] Dance of Arrows: Dmg: Physical | FX: AttackSpeed
#   [W] Wolf's Frenzy: Dmg: Magic | FX: Heal
#   [E] Mounting Dread: Dmg: Physical | CC: Slow | FX: Heal
#   [R] Lamb's Respite: CC: Grounded | FX: Heal
#
# Zeri:
#   [P] Living Battery: 1 relationships
#   [Q] Burst Fire: Dmg: Physical
#   [W] Ultrashock Laser: Dmg: Physical | CC: Slow
#   [E] Spark Surge: Dmg: Magic | FX: Dash
#   [R] Lightning Crash: Dmg: Magic,Physical | FX: Movement,AttackSpeed
#
# Jinx:
#   [P] Get Excited!: 3 relationships
#   [Q] Switcheroo!: Dmg: Physical | CC: Slow | FX: AttackSpeed
#   [W] Zap!: Dmg: Physical | CC: Slow
#   [E] Flame Chompers!: Dmg: Magic | CC: Root
#   [R] Super Mega Death Rocket!: Dmg: Physical | FX: Heal
#
# Tahm Kench:
#   [P] An Acquired Taste: 1 relationships
#   [Q] Tongue Lash: Dmg: Magic | CC: Stun,Slow | FX: Heal
#   [W] Abyssal Dive: Dmg: Magic | CC: Knockup
#   [E] Thick Skin: FX: Shield,Heal
#   [R] Devour: Dmg: Magic | CC: Slow,Grounded | FX: Shield,Heal
#
# Briar:
#   [P] Crimson Curse: 1 relationships
#   [Q] Head Rush: Dmg: Physical | CC: Stun
#   [W] Blood Frenzy / Snack Attack: Dmg: Physical | CC: Taunt | FX: Heal,Movement
#   [E] Chilling Scream: Dmg: Magic | CC: Stun,Knockback,Slow | FX: Heal
#   [R] Certain Death: Dmg: Magic | CC: Fear | FX: Movement,Lifesteal
#
# Viego:
#   [P] Sovereign's Domination: 2 relationships
#   [Q] Blade of the Ruined King: Dmg: Physical | FX: Heal
#   [W] Spectral Maw: Dmg: Magic | CC: Stun,Slow | FX: Dash
#   [E] Harrowed Path: FX: Movement,AttackSpeed
#   [R] Heartbreaker: Dmg: Physical | CC: Knockback,Slow | FX: Heal,Blink
#
# Senna:
#   [P] Absolution: 3 relationships
#   [Q] Piercing Darkness: Dmg: Physical | CC: Slow | FX: Heal
#   [W] Last Embrace: Dmg: Physical | CC: Root
#   [E] Curse of the Black Mist: FX: Movement
#   [R] Dawning Shadow: Dmg: Physical | FX: Shield
#
# Lucian:
#   [P] Lightslinger: 3 relationships
#   [Q] Piercing Light: Dmg: Physical
#   [W] Ardent Blaze: Dmg: Magic | FX: Movement
#   [E] Relentless Pursuit: FX: Dash
#   [R] The Culling: Dmg: Physical
#
# Zed:
#   [P] Contempt for the Weak: 2 relationships
#   [Q] Razor Shuriken: Dmg: Physical
#   [W] Living Shadow: FX: Dash
#   [E] Shadow Slash: Dmg: Physical | CC: Slow
#   [R] Death Mark: Dmg: Physical | FX: Dash
#
# Kled:
#   [P] Skaarl, the Cowardly Lizard: 1 relationships
#   [Q] Bear Trap on a Rope: Dmg: Physical | CC: Knockback,Slow
#   [W] Violent Tendencies: Dmg: Physical | FX: Heal,AttackSpeed
#   [E] Jousting: Dmg: Physical | FX: Dash,Movement
#   [R] Chaaaaaaaarge!!!: Dmg: Magic | CC: Knockback | FX: Shield,Heal
#
# Ekko:
#   [P] Z-Drive Resonance: 1 relationships
#   [Q] Timewinder: Dmg: Magic | CC: Slow
#   [W] Parallel Convergence: Dmg: Magic | CC: Stun,Slow | FX: Shield,Heal
#   [E] Phase Dive: Dmg: Magic | FX: Dash,Blink
#   [R] Chronobreak: Dmg: Magic | FX: Heal,Blink
#
# Qiyana:
#   [P] Royal Privilege: 0 relationships
#   [Q] Elemental Wrath / Edge of Ixtal: Dmg: Physical | CC: Root,Slow | FX: Heal,Stealth
#   [W] Terrashape: Dmg: Magic | FX: Dash,Movement
#   [E] Audacity: Dmg: Physical | FX: Dash
#   [R] Supreme Display of Talent: Dmg: Physical | CC: Stun,Knockback | FX: Heal
#
# Vi:
#   [P] Blast Shield: 1 relationships
#   [Q] Vault Breaker: Dmg: Physical | CC: Slow | FX: Dash
#   [W] Denting Blows: Dmg: Physical | FX: Shield,Heal
#   [E] Relentless Force: Dmg: Physical
#   [R] Cease and Desist: Dmg: Physical | CC: Stun,Grounded | FX: Dash
#
# Aatrox:
#   [P] Deathbringer Stance: 3 relationships
#   [Q] The Darkin Blade: Dmg: Physical
#   [W] Infernal Chains: Dmg: Physical | CC: Slow,Grounded
#   [E] Umbral Dash: FX: Heal,Dash
#   [R] World Ender: CC: Fear | FX: Heal,Movement
#
# Nami:
#   [P] Surging Tides: 1 relationships
#   [Q] Aqua Prison: Dmg: Magic | CC: Stun
#   [W] Ebb and Flow: Dmg: Magic | FX: Heal
#   [E] Tidecaller's Blessing: Dmg: Magic | CC: Slow
#   [R] Tidal Wave: Dmg: Magic | CC: Knockup,Slow
#
# Azir:
#   [P] Shurima's Legacy: 0 relationships
#   [Q] Conquering Sands: Dmg: Magic | CC: Slow
#   [W] Arise!: Dmg: Magic
#   [E] Shifting Sands: Dmg: Magic | FX: Shield,Dash
#   [R] Emperor's Divide: Dmg: Magic | CC: Knockback
#
# Yuumi:
#   [P] Feline Friendship: 1 relationships
#   [Q] Prowling Projectile: Dmg: Magic | CC: Slow
#   [W] You and Me!: FX: Shield,Heal
#   [E] Zoomies: Dmg: Magic | FX: Shield,Movement
#   [R] Final Chapter: Dmg: Magic | CC: Slow | FX: Shield,Heal
#
# Samira:
#   [P] Daredevil Impulse: 2 relationships
#   [Q] Flair: Dmg: Physical
#   [W] Blade Whirl: Dmg: Physical
#   [E] Wild Rush: Dmg: Magic | FX: Dash,AttackSpeed
#   [R] Inferno Trigger: Dmg: Physical | FX: Lifesteal
#
# Thresh:
#   [P] Damnation: 2 relationships
#   [Q] Death Sentence: Dmg: Magic | CC: Stun,Taunt
#   [W] Dark Passage: FX: Shield,Dash
#   [E] Flay: Dmg: Magic | CC: Slow
#   [R] The Box: Dmg: Magic | CC: Slow
#
# Illaoi:
#   [P] Prophet of an Elder God: 2 relationships
#   [Q] Tentacle Smash: Dmg: Physical
#   [W] Harsh Lesson: Dmg: Physical | FX: Heal
#   [E] Test of Spirit: CC: Slow
#   [R] Leap of Faith: Dmg: Physical | CC: Grounded
#
# Rek'Sai:
#   [P] Fury of the Xer'Sai: 1 relationships
#   [Q] Queen's Wrath / Prey Seeker: Dmg: Physical | FX: AttackSpeed
#   [W] Burrow / Un-burrow: CC: Knockup,Grounded | FX: Movement
#   [E] Furious Bite / Tunnel: Dmg: Physical,True
#   [R] Void Rush: Dmg: Physical | FX: Heal
#
# Ivern:
#   [P] Friend of the Forest: 0 relationships
#   [Q] Rootcaller: Dmg: Magic | CC: Root | FX: Dash
#   [W] Brushmaker: Dmg: Magic
#   [E] Triggerseed: Dmg: Magic | CC: Slow | FX: Shield
#   [R] Daisy!: Dmg: Magic | CC: Knockup
#
# Kalista:
#   [P] Martial Poise: 0 relationships
#   [Q] Pierce: Dmg: Physical | FX: Dash
#   [W] Sentinel: Dmg: Magic | FX: Heal
#   [E] Rend: Dmg: Physical | CC: Slow
#   [R] Fate's Call: CC: Knockback | FX: Dash,Blink
#
# Bard:
#   [P] Traveler's Call: 3 relationships
#       CC: Slow
#   [Q] Cosmic Binding: Dmg: Magic | CC: Stun,Slow
#   [W] Caretaker's Shrine: FX: Heal,Movement
#   [E] Magical Journey: no special effects
#   [R] Tempered Fate: no special effects
#
# Rakan:
#   [P] Fey Feathers: 1 relationships
#   [Q] Gleaming Quill: Dmg: Magic | FX: Heal
#   [W] Grand Entrance: Dmg: Magic | CC: Knockup | FX: Dash
#   [E] Battle Dance: FX: Shield,Dash
#   [R] The Quickness: Dmg: Magic | CC: Charm | FX: Movement
#
# Xayah:
#   [P] Clean Cuts: 0 relationships
#   [Q] Double Daggers: Dmg: Physical
#   [W] Deadly Plumage: FX: Movement,AttackSpeed
#   [E] Bladecaller: Dmg: Physical | CC: Root
#   [R] Featherstorm: Dmg: Physical
#
# Ornn:
#   [P] Living Forge: 2 relationships
#   [Q] Volcanic Rupture: Dmg: Physical | CC: Slow,Grounded
#   [W] Bellows Breath: Dmg: Magic | FX: Heal
#   [E] Searing Charge: Dmg: Physical | CC: Knockup
#   [R] Call of the Forge God: Dmg: Magic | CC: Knockup,Slow | FX: Dash
#
# Sylas:
#   [P] Petricite Burst: 3 relationships
#   [Q] Chain Lash: Dmg: Magic | CC: Slow
#   [W] Kingslayer: Dmg: Magic | FX: Heal
#   [E] Abscond / Abduct: Dmg: Magic | CC: Knockup | FX: Dash
#   [R] Hijack: no special effects
#
# Neeko:
#   [P] Inherent Glamour: 1 relationships
#   [Q] Blooming Burst: Dmg: Magic
#   [W] Shapesplitter: Dmg: Magic | FX: Stealth,Movement
#   [E] Tangle-Barbs: Dmg: Magic | CC: Root
#   [R] Pop Blossom: Dmg: Magic | CC: Stun,Knockup
#
# Aphelios:
#   [P] The Hitman and the Seer: 0 relationships
#   [Q] Weapon Abilites: CC: Root,Slow
#   [W] Phase: no special effects
#   [E] Weapon Queue System: no special effects
#   [R] Moonlight Vigil: Dmg: Physical
#
# Rell:
#   [P] Break the Mold: 3 relationships
#   [Q] Shattering Strike: Dmg: Magic | CC: Stun | FX: Shield
#   [W] Ferromancy: Crash Down: Dmg: Magic | CC: Knockup,Slow | FX: Shield,Movement
#   [E] Full Tilt: Dmg: Magic | FX: Heal,Movement
#   [R] Magnet Storm: Dmg: Magic
#
# Pyke:
#   [P] Gift of the Drowned Ones: 3 relationships
#   [Q] Bone Skewer: Dmg: Physical | CC: Slow
#   [W] Ghostwater Dive: FX: Movement
#   [E] Phantom Undertow: Dmg: Physical | CC: Stun | FX: Dash
#   [R] Death From Below: Dmg: Physical | FX: Heal,Blink
#
# Vex:
#   [P] Doom 'n Gloom: 2 relationships
#       CC: Fear
#   [Q] Mistral Bolt: Dmg: Magic
#   [W] Personal Space: Dmg: Magic | FX: Shield
#   [E] Looming Darkness: Dmg: Magic | CC: Slow
#   [R] Shadow Surge: Dmg: Magic | FX: Dash
#
# Yone:
#   [P] Way of the Hunter: 2 relationships
#   [Q] Mortal Steel: Dmg: Physical | CC: Knockup | FX: Dash
#   [W] Spirit Cleave: Dmg: Magic,Physical | FX: Shield,Heal
#   [E] Soul Unbound: FX: Movement
#   [R] Fate Sealed: Dmg: Magic,Physical | CC: Knockup | FX: Blink
#
# Ambessa:
#   [P] Drakehound's Step: 3 relationships
#   [Q] Cunning Sweep / Sundering Slam: Dmg: Physical | FX: Heal
#   [W] Repudiation: Dmg: Physical | CC: Grounded | FX: Shield
#   [E] Lacerate: Dmg: Physical | CC: Slow | FX: Dash
#   [R] Public Execution: Dmg: Physical | CC: Stun,Grounded,Suppress | FX: Heal,Blink
#
# Mel:
#   [P] Searing Brilliance: 0 relationships
#   [Q] Radiant Volley: Dmg: Magic
#   [W] Rebuttal: Dmg: Magic | FX: Movement
#   [E] Solar Snare: Dmg: Magic | CC: Root,Slow
#   [R] Golden Eclipse: Dmg: Magic
#
# Yunara:
#   [P] Vow of the First Lands: 2 relationships
#   [Q] Cultivation of Spirit: Dmg: Magic,Physical | FX: AttackSpeed
#   [W] Arc of Judgment | Arc of Ruin: Dmg: Magic | CC: Slow
#   [E] Kanmei's Steps | Untouchable Shadow: FX: Dash,Movement
#   [R] Transcend One's Self: no special effects
#
# Sett:
#   [P] Pit Grit: 1 relationships
#   [Q] Knuckle Down: Dmg: Physical | FX: Heal,Movement
#   [W] Haymaker: Dmg: Physical,True | FX: Shield
#   [E] Facebreaker: Dmg: Physical | CC: Stun,Slow
#   [R] The Show Stopper: Dmg: Physical | CC: Slow,Grounded,Suppress | FX: Heal
#
# Lillia:
#   [P] Dream-Laden Bough: 2 relationships
#   [Q] Blooming Blows: Dmg: Magic,True | FX: Movement
#   [W] Watch Out! Eep!: Dmg: Magic
#   [E] Swirlseed: Dmg: Magic | CC: Slow
#   [R] Lilting Lullaby: Dmg: Magic
#
# Gwen:
#   [P] A Thousand Cuts: 2 relationships
#   [Q] Snip Snip!: Dmg: Magic,True | FX: Heal
#   [W] Hallowed Mist: no special effects
#   [E] Skip 'n Slash: Dmg: Magic | FX: Dash,AttackSpeed
#   [R] Needlework: Dmg: Magic | CC: Slow
#
# Renata Glasc:
#   [P] Leverage: 0 relationships
#   [Q] Handshake: Dmg: Magic | CC: Stun,Root
#   [W] Bailout: FX: Heal,Movement
#   [E] Loyalty Program: Dmg: Magic | CC: Slow | FX: Shield
#   [R] Hostile Takeover: FX: AttackSpeed
#
# Aurora:
#   [P] Spirit Abjuration: 1 relationships
#   [Q] Twofold Hex: Dmg: Magic | FX: Heal
#   [W] Across the Veil: FX: Stealth,Movement
#   [E] The Weirding: Dmg: Magic | CC: Slow
#   [R] Between Worlds: Dmg: Magic | CC: Stun,Slow | FX: Blink
#
# Nilah:
#   [P] Joy Unending: 2 relationships
#   [Q] Formless Blade: Dmg: Physical | FX: Shield,Heal
#   [W] Jubilant Veil: Dmg: Magic | FX: Movement
#   [E] Slipstream: Dmg: Physical | FX: Dash
#   [R] Apotheosis: Dmg: Physical | FX: Shield,Heal
#
# K'Sante:
#   [P] Dauntless Instinct: 0 relationships
#   [Q] Ntofo Strikes: Dmg: Physical | CC: Stun,Slow
#   [W] Path Maker: Dmg: Physical,True | CC: Stun,Knockback | FX: Heal,Dash
#   [E] Footwork: FX: Shield,Dash
#   [R] All Out: Dmg: Physical | CC: Knockback | FX: Heal,Dash
#
# Smolder:
#   [P] Dragon Practice: 0 relationships
#   [Q] Super Scorcher Breath: Dmg: Magic,Physical,True | FX: Heal
#   [W] Achooo!: Dmg: Magic,Physical | CC: Slow
#   [E] Flap, Flap, Flap: Dmg: Magic,Physical | FX: Heal,Movement
#   [R] MMOOOMMMM!: Dmg: Physical | CC: Slow | FX: Heal
#
# Milio:
#   [P] Fired Up!: 0 relationships
#   [Q] Ultra Mega Fire Kick: Dmg: Magic | CC: Knockback,Slow
#   [W] Cozy Campfire: FX: Heal
#   [E] Warm Hugs: FX: Shield,Movement
#   [R] Breath of Life: FX: Heal
#
# Zaahen:
#   [P] Cultivation of War: 1 relationships
#   [Q] The Darkin Glaive: Dmg: Physical | CC: Knockup | FX: Heal
#   [W] Dreaded Return: Dmg: Physical
#   [E] Aureate Rush: Dmg: Magic,Physical | FX: Heal,Dash
#   [R] Grim Deliverance: Dmg: Physical | FX: Heal
#
# Hwei:
#   [P] Signature of the Visionary: 1 relationships
#   [Q] Subject: Disaster: Dmg: Magic | CC: Slow | FX: Heal
#   [W] Subject: Serenity: Dmg: Magic | FX: Shield,Movement
#   [E] Subject: Torment: Dmg: Magic | CC: Root,Slow
#   [R] Spiraling Despair: Dmg: Magic | CC: Slow
#
# Naafiri:
#   [P] We Are More: 0 relationships
#   [Q] Darkin Daggers: Dmg: Physical | FX: Heal
#   [W] The Call of the Pack: Dmg: Physical | FX: Movement
#   [E] Eviscerate: Dmg: Physical | FX: Heal,Dash
#   [R] Hounds' Pursuit: Dmg: Physical | CC: Slow | FX: Shield,Dash
#
#
# 🎉 Created 2068 ability relationships!

# %%
# Query 3: Find all abilities that scale with AP
query = """
MATCH (c:Champion)-[:HAS_ABILITY]->(a:Ability)
MATCH (a)-[:SCALES_WITH]->(s:Stat {name: 'AP'})
RETURN c.name as champion, count(a) as ap_abilities
ORDER BY ap_abilities DESC
LIMIT 5
"""

results = graph.query(query)
print("\nChampions with Most AP Scaling Abilities:")
for row in results:
    print(f"  {row['champion']}: {row['ap_abilities']} abilities")
# Out:
# Champions with Most AP Scaling Abilities:
#   Veigar: 2 abilities
#   Singed: 1 abilities
#   Ryze: 1 abilities
#   Akali: 1 abilities
#   Vladimir: 1 abilities
